# %% [markdown]
# <a href="https://colab.research.google.com/github/dhakadarind-204/Algo_Lab/blob/main/Lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Travelling Salesman Problem using Dynamic Programming.
# Problem Description:
# Given a set of cities and distances, find the shortest possible route that visits each city once and returns to the starting city.

# %% [markdown]
# #Theory
# TSP uses dynamic programming with bit masking. Store results of visited subsets to reduce repeated work.
#
# ## Algorithm
# 1. Start from source city
# 2. Mark visited cities using bit mask
# 3. Try all unvisited cities
# 4. Choose minimum cost path
# 5. Return to source city

# %%
def tsp(graph):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))
                if new_cost < ans:
                    ans = new_cost


        dp[city][mask] = ans
        return ans

    return visit(0, 1)

# %%
graph = [
[0, 10, 15, 20],
[10, 0, 35, 25],
[15, 35, 0, 30],
[20, 25, 30, 0]
]

print("Minimum travelling cost:", tsp(graph))
# Out:
# Minimum travelling cost: 80

# %% [markdown]
# # Exercise
# 1. Print path of cities visited
# 2. Take graph input from user
# 3. Test with different number of cities

# %% [markdown]
# Print path of cities visited

# %%
def tsp(graph):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]
    cities = [[-1]*(1<<n) for _ in range(n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))

                if new_cost < ans:
                    ans = new_cost
                    cities[city][mask] = next_city

        dp[city][mask] = ans
        return ans

    min_cost = visit(0, 1)
    path = [0]
    mask = 1
    city = 0

    while True:
        next_city = cities[city][mask]
        if next_city == -1:
            break
        path.append(next_city)
        mask = mask | (1<<next_city)
        city = next_city

    path.append(0)

    return min_cost, path

# %% [markdown]
# 2. Take graph input from user

# %%
graph = []
n_cities = int(input("Enter no of cities: "))
for i in range(n_cities):
  dist = list(map(int, input(f"Enter costs from {i}: ").split()))
  graph.append(dist)
cost, path = tsp(graph)
print("Minimum travelling cost:",cost)
print("Path:",path)
# Out:
# Enter no of cities: 4
# Enter costs from 0: 0 2 5 2
# Enter costs from 1:  1 5 6 4
# Enter costs from 2: 1 3 5 6
# Enter costs from 3: 4 6 1
# Minimum travelling cost: 7
# Path: [0, 3, 2, 1, 0]

# %% [markdown]
# 3. Test with different number of cities

# %%
graph = []
n_cities = int(input("Enter no of cities: "))
for i in range(n_cities):
  dist = list(map(int, input(f"Enter costs from {i}: ").split()))
  graph.append(dist)
for i in range(n_cities):
  print(graph[i])
cost, path = tsp(graph)
print("Minimum travelling cost:",cost)
print("Path:",path)
# Out:
# Enter no of cities: 4
# Enter costs from 0: 1 2 5 8
# Enter costs from 1: 4 5 8 6
# Enter costs from 2: 5 6 2 3
# Enter costs from 3: 4 5 6 3
# [1, 2, 5, 8]
# [4, 5, 8, 6]
# [5, 6, 2, 3]
# [4, 5, 6, 3]
# Minimum travelling cost: 17
# Path: [0, 1, 2, 3, 0]
